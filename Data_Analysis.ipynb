# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumyaMajumder90/Data-Analysis/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Making a dictionary**
# We will do our work in our custom dataset

# %%
dict1 = {
    "name": ['harry','rohan', 'praveen', 'Soumya'],
    "marks": [92,34,24,15],
    "city": ['rampur', 'kolkata', 'sonbhadra', 'siliguri']

}

# %% [markdown]
# **Step 3:  Making a DataFrame**
#
# Dataframe can be considered as a excel sheet. To analyse big data

# %%
df= pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks       city
# 0    harry     92     rampur
# 1    rohan     34    kolkata
# 2  praveen     24  sonbhadra
# 3   Soumya     15   siliguri

# %% [markdown]
# **Steps to make a dataframe to excel file(csv)**

# %%
df.to_csv('Friends.csv')
#df.to_csv('Friends.csv', index= False) this means index(default) will be deleted from the csv file

# %% [markdown]
# **Df.head**
# It shows the first two or three rows of the dataframe
#
# **df.tail**
# It shows the last two or three rows of the dataframe

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
df.tail(2)
# Out:
#       name  marks       city
# 2  praveen     24  sonbhadra
# 3   Soumya     15   siliguri

# %% [markdown]
# **df.describe**
#
# It will show mathematical parameters of numerical datas in the dataset
# (count,min max mean)

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.25000
# std    34.71191
# min    15.00000
# 25%    21.75000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %% [markdown]
# soumya = pd.read_csv('friends.csv)

# %%
soumya = pd.read_excel('/content/Book.xlsx') #pd.read_csv read the csv and copy it to variable 'soumya'

soumya  #show the value of soumya
# Out:
#    Unnamed: 0   Train  Speed       City
# 0           0   12322     34     rampur
# 1           1   12534    123    kolkata
# 2           2  125654     67   bairelly
# 3           3  564523     87  antartica

# %%
soumya['Speed']
# Out:
# 0     34
# 1    123
# 2     67
# 3     87
# Name: Speed, dtype: int64

# %% [markdown]
# [link text](https://)

# %%
soumya['Speed'][0]
# Out:
# 34

# %%
soumya['Speed'][0]=50
# Out:
# <ipython-input-21-1cca02952e58>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   soumya['Speed'][0]=50

# %%
soumya  #changed the value of index 0 to 50
# Out:
#    Unnamed: 0   Train  Speed       City
# 0           0   12322     50     rampur
# 1           1   12534    123    kolkata
# 2           2  125654     67   bairelly
# 3           3  564523     87  antartica

# %%
soumya.index = ['first', 'second', 'third', 'fourth']
soumya
# Out:
#         Unnamed: 0   Train  Speed       City
# first            0   12322     50     rampur
# second           1   12534    123    kolkata
# third            2  125654     67   bairelly
# fourth           3  564523     87  antartica

# %% [markdown]
# **What is Pandas**
# 1. Pandas is a open souce data analysis library written python
# 2. increase power and speed of numpy to make data analysis and preprocessing
# 3.It provides rich and highly robust data operations
#
# Pandas has two types of data structure:
# a)Series- its one dimensional array with inde, it stores a single co,umn or row of data in dataframe
# b)Dataframe: Its a tabular spreadsheet like structure representing rows each of which contains one or multiple column

# %%
ser= pd.Series(np.random.rand(34)) #it will give a seried from 0 to 34
ser
# Out:
# 0     0.333576
# 1     0.073552
# 2     0.784515
# 3     0.576185
# 4     0.113242
# 5     0.404290
# 6     0.179922
# 7     0.022801
# 8     0.811911
# 9     0.054437
# 10    0.493453
# 11    0.726394
# 12    0.945878
# 13    0.243867
# 14    0.932910
# 15    0.978361
# 16    0.216448
# 17    0.288432
# 18    0.545702
# 19    0.899733
# 20    0.732625
# 21    0.324735
# 22    0.296359
# 23    0.202349
# 24    0.384481
# 25    0.008431
# 26    0.908069
# 27    0.621411
# 28    0.588586
# 29    0.971406
# 30    0.980440
# 31    0.244103
# 32    0.665472
# 33    0.087620
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Lets create a dataframe named 'newdf and then using np.random.rand we will generate some random numbers.
#
# it will

# %%
newdf =pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.172937  0.157653  0.217678  0.903869  0.841403
# 1    0.698010  0.193837  0.326248  0.569517  0.703449
# 2    0.261224  0.576612  0.918925  0.631269  0.479160
# 3    0.909114  0.176569  0.648505  0.407070  0.100686
# 4    0.178579  0.934390  0.956616  0.681359  0.997797
# ..        ...       ...       ...       ...       ...
# 329  0.501512  0.792771  0.273400  0.991538  0.643153
# 330  0.444802  0.970450  0.599952  0.089921  0.734359
# 331  0.514023  0.966866  0.131049  0.901803  0.940040
# 332  0.005084  0.381855  0.049346  0.289531  0.063081
# 333  0.897838  0.288594  0.704981  0.052785  0.149697
#
# [334 rows x 5 columns]

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.497968    0.495215    0.521577    0.510368    0.490916
# std      0.290956    0.293367    0.280612    0.292793    0.294972
# min      0.003901    0.001052    0.005165    0.006124    0.000175
# 25%      0.243202    0.230677    0.281131    0.256370    0.235546
# 50%      0.493439    0.497816    0.538986    0.534694    0.513798
# 75%      0.764731    0.745488    0.738573    0.764485    0.718006
# max      0.990190    0.999405    0.995487    0.999867    0.997797

# %%
newdf[0][0]= "harry"
newdf.dtypes #will show what is the data types of the column in dataframe
# Out:
# <ipython-input-6-8ca9131dc8cf>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'harry' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newdf[0][0]= "harry"
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0     harry  0.157653  0.217678  0.903869  0.841403
# 1   0.69801  0.193837  0.326248  0.569517  0.703449
# 2  0.261224  0.576612  0.918925  0.631269  0.479160
# 3  0.909114  0.176569  0.648505  0.407070  0.100686
# 4  0.178579  0.934390  0.956616  0.681359  0.997797

# %% [markdown]
# **Next Step**
# **Lets convert this into numpy array**
#
# newdf.to_numpy()

# %%
newdf.to_numpy()
# Out:
# array([['harry', 0.15765348932347734, 0.21767840193060417,
#         0.9038685866066201, 0.8414025937766066],
#        [0.6980096705806178, 0.19383739056285065, 0.3262483097879497,
#         0.5695168312175071, 0.7034488850941981],
#        [0.2612235650123196, 0.5766120683229079, 0.9189252299075741,
#         0.6312693052753934, 0.4791597635147189],
#        ...,
#        [0.5140230314668516, 0.9668659967522953, 0.13104917327759535,
#         0.9018026253501152, 0.9400404746578854],
#        [0.005083516791760112, 0.38185515184130736, 0.04934647717437535,
#         0.28953070983835183, 0.06308133969775898],
#        [0.8978377596035684, 0.2885935234690389, 0.7049811224974409,
#         0.05278493722122146, 0.14969662673731987]], dtype=object)

# %%
newdf[0][0]= 0.3

# %% [markdown]
# **Transpose of the dataframe**

# %%
newdf.T
# Out:
#         0         1         2         3         4         5         6    \
# 0       0.3   0.69801  0.261224  0.909114  0.178579  0.085078  0.929781
# 1  0.157653  0.193837  0.576612  0.176569   0.93439  0.260021  0.458128
# 2  0.217678  0.326248  0.918925  0.648505  0.956616  0.672314  0.103165
# 3  0.903869  0.569517  0.631269   0.40707  0.681359  0.353851  0.730073
# 4  0.841403  0.703449   0.47916  0.100686  0.997797  0.000175  0.271892
#
#         7         8         9    ...       324       325       326       327  \
# 0  0.762516  0.518509  0.166329  ...  0.078149   0.34673  0.437847  0.045944
# 1  0.422125  0.681753   0.12829  ...  0.242748  0.767231   0.11907  0.883317
# 2  0.744188  0.060613  0.455594  ...  0.739719  0.960612  0.985334  0.059716
# 3  0.769264  0.652148  0.256872  ...  0.334526  0.155717  0.505524  0.699557
# 4  0.427531  0.778487  0.578552  ...  0.229835  0.079427  0.645392  0.040032
#
#         328       329       330       331       332       333
# ...

# %% [markdown]
# **How to sort Index**
#
# Right now it is sorted now. lets sort it in reverse
#
# *newdf.sort_index(axis=0, ascending= False)*
#
# Lets talk about this. here axis means the rows
# Axis = 0, row and
# Axis=1, it is column
#  and ascending is by default *True*. If we do this false then it means like it will be in descending order

# %%
newdf.sort_index(axis=0, ascending= False)
# Out:
#             0         1         2         3         4
# 333  0.897838  0.288594  0.704981  0.052785  0.149697
# 332  0.005084  0.381855  0.049346  0.289531  0.063081
# 331  0.514023  0.966866  0.131049  0.901803  0.940040
# 330  0.444802  0.970450  0.599952  0.089921  0.734359
# 329  0.501512  0.792771  0.273400  0.991538  0.643153
# ..        ...       ...       ...       ...       ...
# 4    0.178579  0.934390  0.956616  0.681359  0.997797
# 3    0.909114  0.176569  0.648505  0.407070  0.100686
# 2    0.261224  0.576612  0.918925  0.631269  0.479160
# 1     0.69801  0.193837  0.326248  0.569517  0.703449
# 0         0.3  0.157653  0.217678  0.903869  0.841403
#
# [334 rows x 5 columns]

# %% [markdown]
# Lets talk about Copy and View.
#
# newdf2 = newdf  *It is a view of newdf not copy*. It works like newdf2 is a pointer to newdf
#
# If we have to copy instead of view then we have to do:
#
# *newdf2= newdf.copy
# or
# newdf2= newdf[:]
# *
#
# if we change any value in newdf2 then it will also get changed in newdf. Lets try that

# %%
newdf2 =newdf
newdf[0][0]= 9783

# %%
newdf #see the value has changed,
# Out:
#             0         1         2         3         4
# 0        9783  0.157653  0.217678  0.903869  0.841403
# 1     0.69801  0.193837  0.326248  0.569517  0.703449
# 2    0.261224  0.576612  0.918925  0.631269  0.479160
# 3    0.909114  0.176569  0.648505  0.407070  0.100686
# 4    0.178579  0.934390  0.956616  0.681359  0.997797
# ..        ...       ...       ...       ...       ...
# 329  0.501512  0.792771  0.273400  0.991538  0.643153
# 330  0.444802  0.970450  0.599952  0.089921  0.734359
# 331  0.514023  0.966866  0.131049  0.901803  0.940040
# 332  0.005084  0.381855  0.049346  0.289531  0.063081
# 333  0.897838  0.288594  0.704981  0.052785  0.149697
#
# [334 rows x 5 columns]

# %% [markdown]
# If we have to set any value to any data in dataframe the we have to use **loc**
#
# *newdf.loc[0,0]= 654*
#
# newdf.loc[

# %%
newdf.loc[0,0]= 654
newdf.head(2)
# Out:
#          0         1         2         3         4
# 0      654  0.157653  0.217678  0.903869  0.841403
# 1  0.69801  0.193837  0.326248  0.569517  0.703449

# %% [markdown]
# **newdf.drop(0, axis=1)**
#
#  this will drop the column 0 from the df

# %%
newdf.drop(0, axis=1)
# Out:
#             1         2         3         4
# 0    0.157653  0.217678  0.903869  0.841403
# 1    0.193837  0.326248  0.569517  0.703449
# 2    0.576612  0.918925  0.631269  0.479160
# 3    0.176569  0.648505  0.407070  0.100686
# 4    0.934390  0.956616  0.681359  0.997797
# ..        ...       ...       ...       ...
# 329  0.792771  0.273400  0.991538  0.643153
# 330  0.970450  0.599952  0.089921  0.734359
# 331  0.966866  0.131049  0.901803  0.940040
# 332  0.381855  0.049346  0.289531  0.063081
# 333  0.288594  0.704981  0.052785  0.149697
#
# [334 rows x 4 columns]

# %%
newdf.loc[[1,2],[2, 3]] #will give the locality which are mentioned
# Out:
#           2         3
# 1  0.326248  0.569517
# 2  0.918925  0.631269

# %% [markdown]
# If we do newdf.loc[:,[1,2]] it will five all the rows but only 1 and 2 column
#
# and newdf.loc[:,[1,2]]=> all columns are fetched.

# %%
newdf.loc[(newdf[0])<0.3] #will return all the rows where it is less than 0.3
# Out:
#             0         1         2         3         4
# 2    0.261224  0.576612  0.918925  0.631269  0.479160
# 4    0.178579  0.934390  0.956616  0.681359  0.997797
# 5    0.085078  0.260021  0.672314  0.353851  0.000175
# 9    0.166329  0.128290  0.455594  0.256872  0.578552
# 10   0.048723  0.504302  0.549026  0.828413  0.511394
# ..        ...       ...       ...       ...       ...
# 320  0.252981  0.507823  0.352142  0.759721  0.839659
# 322   0.19281  0.226023  0.817181  0.563621  0.048812
# 324  0.078149  0.242748  0.739719  0.334526  0.229835
# 327  0.045944  0.883317  0.059716  0.699557  0.040032
# 332  0.005084  0.381855  0.049346  0.289531  0.063081
#
# [102 rows x 5 columns]

# %% [markdown]
# newdf.loc[(newdf[0])<0.3 & newdf[1]<0.2)
#
# **iloc**
#
# when targeting with index then use loc and when targeting using
#
# what iloc is doing will print as matrix
#
# newdf.iloc[0,4] then will give 0.4 data

# %% [markdown]
# **Some more functions of pandas**
#
# *DropNa* :
#  It will drop the NaN(not available data) from the df
#
#  *isnull* : will give information where the value is null
#
#  *drop_duplocates*: will drop duplicates value
#
#  **Note :** Always use loc when setting or else sometimes you will forget why it is recording the same value despite setting the value. It might be returning any copy or view version.
#
#  **Note :** always use pandas library docs.
